# %%
import os
import cv2

vid_path = '../db/original/0831/'
pic_path = '../db/pic/'
pic_dir = 'JJ_r_1/'
vid_name = 'JJ_r_1.avi'
pic_name = 'JJ_r_1'

try: 
    if not(os.path.isdir(pic_path + pic_dir)):
        os.makedirs(os.path.join(pic_path + pic_dir))
except OSError as e:
    if e.errno != errno.EEXIST:
        print("Failed to create directory")
        raise

        
vidcap = cv2.VideoCapture(vid_path + vid_name)
        
cnt = 1
success = True
        
while success :
    success, img = vidcap.read()
    cv2.imwrite(pic_path + pic_dir + pic_name + '%d.jpg' % cnt, img)
    print("saved image %d.jpg" % cnt)
    
    if cv2.waitKey(10) == 27:
        break
        
    cnt += 1
# Out:
# saved image 1.jpg
# saved image 2.jpg
# saved image 3.jpg
# saved image 4.jpg
# saved image 5.jpg
# saved image 6.jpg
# saved image 7.jpg
# saved image 8.jpg
# saved image 9.jpg
# saved image 10.jpg
# saved image 11.jpg
# saved image 12.jpg
# saved image 13.jpg
# saved image 14.jpg
# saved image 15.jpg
# saved image 16.jpg
# saved image 17.jpg
# saved image 18.jpg
# saved image 19.jpg
# saved image 20.jpg
# saved image 21.jpg
# saved image 22.jpg
# saved image 23.jpg
# saved image 24.jpg
# saved image 25.jpg
# saved image 26.jpg
# saved image 27.jpg
# saved image 28.jpg
# saved image 29.jpg
# saved image 30.jpg
# saved image 31.jpg
# saved image 32.jpg
# saved image 33.jpg
# saved image 34.jpg
# saved image 35.jpg
# saved image 36.jpg
# saved image 37.jpg
# saved image 38.jpg
# saved image 39.jpg
# saved image 40.jpg
# saved image 41.jpg
# saved image 42.jpg
# saved image 43.jpg
# saved image 44.jpg
# saved image 45.jpg
# saved image 46.jpg
# saved image 47.jpg
# saved image 48.jpg
# ...

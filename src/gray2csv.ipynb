# %%
import numpy as np
from PIL import Image
import csv
import os 

gray_path = '../db/gray/'
img_path = '../db/pic/'
vid_name = 'jayden_left/'


img_list = os.listdir(img_path + vid_name)

try: 
    if not(os.path.isdir(gray_path + vid_name)):
        os.makedirs(os.path.join(gray_path + vid_name))
except OSError as e:
    if e.errno != errno.EEXIST:
        print("Failed to create directory")
        raise

for j in range (1, len(img_list)+1):
    img_name = (img_path + vid_name + '%d.jpg' % j)
    im = Image.open(img_name).convert("L")

    pic_size = im.size
    pix = np.array(im)


    f = open(gray_path + vid_name + '%d.csv' % j, 'w', encoding='utf-8')
    wr = csv.writer(f)

    for i in range(0,pic_size[1]):
        wr.writerow(pix[i][:])

    f.close()
    
    print("Saved %d.csv" % j)
# Out:
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# ...

# %%
import numpy as np
from PIL import Image
import csv
import os 

gray_path = '../db/gray/'
img_path = '../db/pic/'
vid_name = 'jayden_right/'


img_list = os.listdir(img_path + vid_name)

try: 
    if not(os.path.isdir(gray_path + vid_name)):
        os.makedirs(os.path.join(gray_path + vid_name))
except OSError as e:
    if e.errno != errno.EEXIST:
        print("Failed to create directory")
        raise

for j in range (1, len(img_list)+1):
    img_name = (img_path + vid_name + '%d.jpg' % j)
    im = Image.open(img_name).convert("L")

    pic_size = im.size
    pix = np.array(im)

    cnt = 1

    f = open(gray_path + vid_name + '%d.csv' % j, 'w', encoding='utf-8')
    wr = csv.writer(f)

    for i in range(0,pic_size[1]):
        wr.writerow(pix[i][:])

    f.close()
    
    print("Saved %d.csv" % cnt)
# Out:
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# Saved 1.csv
# ...
